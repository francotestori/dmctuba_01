# %%
import matplotlib.pyplot as plt
import pandas as pd 
import spotipy 
import librosa
import librosa.display
import numpy as np
import matplotlib as mpl
import urllib.request
import seaborn as sns
import tqdm
import scipy
import joblib
import os.path
from pathlib import Path
from IPython.display import Audio, Markdown, Image
from spotipy.oauth2 import SpotifyClientCredentials

# Números y Datos
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform
from scipy.interpolate import interp1d

# Análisis de sonido
import librosa
import librosa.display
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials 

# Machine learning
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

from sklearn.preprocessing import quantile_transform

# Styles
sns.set_context('poster')
sns.set_style('darkgrid')

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
#df_merged_all = pd.read_pickle('../sources/df_merged_all_quantiles_mediana_iqr.pickle')
df_merged_all = pd.read_pickle('../sources/df_todo_1_Uniform.pickle')
len(df_merged_all)
#df_num = df_merged_all
#df_merged_all.head(3).T.tail(20)
# Out:
# 4082

# %%
df_num = df_merged_all.drop(['af_instrumentalness','af_mode','af_popularity','af_time_signature','af_key'],1)#.drop(['af_instrumentalness','af_mode','af_popularity','af_time_signature','af_key'],1)

cols = [c for c in df_num.columns if c.lower()[:3] == 'aa_']
df_num=df_num[cols]
df_num = df_num.rename(columns={col:col[3:] for col in df_num.columns})
df_num['genre']=df_merged_all['genre']

#df_num = df_num.rename(columns={'re':'genero'})
#df_num.columns

list(df_num.columns)
# Out:
# ['confidence_mediana',
#  'loudness_start_mediana',
#  'loudness_max_time_mediana',
#  'loudness_max_mediana',
#  'loudness_end_mediana',
#  'p00_C_mediana',
#  'p01_C#_mediana',
#  'p02_D_mediana',
#  'p03_D#_mediana',
#  'p04_E_mediana',
#  'p05_F_mediana',
#  'p06_F#_mediana',
#  'p07_G_mediana',
#  'p08_G#_mediana',
#  'p09_A_mediana',
#  'p10_A#_mediana',
#  'p11_B_mediana',
#  't00_mediana',
#  't01_mediana',
#  't02_mediana',
#  't03_mediana',
#  't04_mediana',
#  't05_mediana',
#  't06_mediana',
#  't07_mediana',
#  't08_mediana',
#  't09_mediana',
#  't10_mediana',
#  't11_mediana',
#  'confidence_iqr',
#  'loudness_start_iqr',
#  'loudness_max_time_iqr',
#  'loudness_max_iqr',
#  'loudness_end_iqr',
#  'p00_C_iqr',
#  'p01_C#_iqr',
#  'p02_D_iqr',
#  'p03_D#_iqr',
#  'p04_E_iqr',
#  'p05_F_iqr',
#  'p06_F#_iqr',
#  'p07_G_iqr',
#  'p08_G#_iqr',
#  'p09_A_iqr',
#  'p10_A#_iqr',
#  'p11_B_iqr',
#  't00_iqr',
#  't01_iqr',
#  't02_iqr',
#  't03_iqr',
#  't04_iqr',
#  't05_iqr',
#  't06_iqr',
#  't07_iqr',
#  't08_iqr',
#  't09_iqr',
#  't10_iqr',
#  't11_iqr',
#  'confidence_dif_mediana',
#  'loudness_start_dif_mediana',
#  'loudness_max_time_dif_mediana',
#  'loudness_max_dif_mediana',
#  'loudness_end_dif_mediana',
#  'p00_C_dif_mediana',
#  'p01_C#_dif_mediana',
#  'p02_D_dif_mediana',
#  'p03_D#_dif_mediana',
#  'p04_E_dif_mediana',
#  'p05_F_dif_mediana',
#  'p06_F#_dif_mediana',
#  'p07_G_dif_mediana',
#  'p08_G#_dif_mediana',
#  'p09_A_dif_mediana',
#  'p10_A#_dif_mediana',
#  'p11_B_dif_mediana',
#  't00_dif_mediana',
#  't01_dif_mediana',
#  't02_dif_mediana',
#  't03_dif_mediana',
#  't04_dif_mediana',
#  't05_dif_mediana',
#  't06_dif_mediana',
#  't07_dif_mediana',
#  't08_dif_mediana',
#  't09_dif_mediana',
#  't10_dif_mediana',
#  't11_dif_mediana',
#  'confidence_dif_iqr',
#  'loudness_start_dif_iqr',
#  'loudness_max_time_dif_iqr',
#  'loudness_max_dif_iqr',
#  'loudness_end_dif_iqr',
#  'p00_C_dif_iqr',
#  'p01_C#_dif_iqr',
#  'p02_D_dif_iqr',
#  'p03_D#_dif_iqr',
#  'p04_E_dif_iqr',
#  'p05_F_dif_iqr',
#  'p06_F#_dif_iqr',
#  'p07_G_dif_iqr',
#  'p08_G#_dif_iqr',
#  'p09_A_dif_iqr',
#  'p10_A#_dif_iqr',
#  'p11_B_dif_iqr',
#  't00_dif_iqr',
#  't01_dif_iqr',
#  't02_dif_iqr',
#  't03_dif_iqr',
#  't04_dif_iqr',
#  't05_dif_iqr',
#  't06_dif_iqr',
#  't07_dif_iqr',
#  't08_dif_iqr',
#  't09_dif_iqr',
#  't10_dif_iqr',
#  't11_dif_iqr',
#  'pitch_dif_mediana',
#  'pitch_dif_iqr',
#  'pitch_mediana',
#  'pitch_iqr',
#  'timbre_dif_mediana',
#  'timbre_dif_iqr',
#  'timbre_mediana',
#  'timbre_iqr',
#  'genre']

# %% [raw]
# df_num = df_num.rename(columns={
#     'af_duration_ms': 'duracion',
#     'af_popularity': 'popularidad',
#     'af_danceability': 'bailabilidad',
#     'af_energy': 'energia',
#     'af_key': 'duracion',
#     'af_loudness': 'duracion',
#     'af_mode': 'duracion',
#     'af_speechiness': 'duracion',
#     'af_acousticness': 'duracion',
#     'af_instrumentalness': 'duracion',
#     'af_liveness': 'duracion',
#     'af_valence': 'duracion',
#     'af_tempo': 'duracion',
#     'af_time_signature': 'duracion',
#     'genre': 'genero',
#     })

# %%
def plot_radar_chart_stats(s25,s50,s75,color,ax):
    grupo=s25.name
    labels = s25.index

    angles=np.linspace(0, 2*np.pi, len(s25), endpoint=False)
    angles=np.append(angles,angles[0])
    s25=np.append(s25,s25[0])
    s50=np.append(s50,s50[0])
    s75=np.append(s75,s75[0])

    ax.plot(angles, s50, 'o-', linewidth=1,color=color,markersize=4)
    ax.set_yticklabels([])
    ax.set_thetagrids(angles * 180/np.pi, labels, fontsize=5, color='gray')
    ax.tick_params(pad=-6, direction='out', length=4, color='k', zorder=-1)
    ax.fill_between(angles, s25, s75, alpha=0.2,color=color)
    ax.set_title(grupo, fontsize=12, loc='left')
    ax.grid(True)
    ax.set_ylim(0,1)

# %%
grouped = df_num.groupby('genre')

normalized_stats_25_ = grouped.quantile(.25)
normalized_stats_50_ = grouped.quantile(.5)
normalized_stats_75_ = grouped.quantile(.75)
df_num.head(20)
# Out:
#                         confidence_mediana  loudness_start_mediana  \
# id
# 4d3XHYFFuYYzxWr2cJ6yQl            0.967474                0.079165
# 3X3p3u03P8eFL8WTH0oaaU            0.834596                0.218877
# 4KlXeaheot0OI9PoOWspvZ            0.955623                0.258710
# 3j76McoUI18gDoqxYE14Bu            0.782492                0.247528
# 4zxd4tiXPlWMqoJltbVTbE            0.871843                0.228805
# 4LInRUJ6XN1TVnoRVAFcdB            0.971797                0.086447
# 16QhvfPMBLpo7sFqOqTff3            0.531746                0.327450
# 2kF9Ijd7I2Kk2P4bYqUmzG            0.983413                0.187801
# 7pKWTcPfT9mg2iAhobFHpS            0.986086                0.198796
# 6cjjUuY51c5SwTABCVPSYH            0.890110                0.297161
# 0jIjMIGol799k7v3kmD0ZS            0.860831                0.221763
# 5nrpIB2dVUvhRUs5R9YJ3W            0.820707                0.168919
# 1POLDZ0XBX9ycnCkxVKCoZ            0.760777                0.355791
# 2d64G7VaZdHQuAquz5HQNu            0.957441                0.165355
# 4BD61oILBbkkSojO7lcBPA            0.622165                0.312524
# 44MyZZa2SPW0BO9XcmlU9F            0.893493                0.375131
# 7FXj7Qg3YorUxdrzvrcY25            0.864198                0.259105
# 0T1EaGm6b9eM7xBf4F1hlc            0.773277                0.468817
# 08mNpIgvFDORGhekbe0n7A            0.900505                0.283677
# 0efBjbKXXPXqUu5HmZHzW5            0.555556                0.367547
#
#                         loudness_max_time_mediana  loudness_max_mediana  \
# id
# 4d3XHYFFuYYzxWr2cJ6yQl                   0.121319              0.172266
# 3X3p3u03P8eFL8WTH0oaaU                   0.487153              0.268072
# 4KlXeaheot0OI9PoOWspvZ                   0.690679              0.398774
# 3j76McoUI18gDoqxYE14Bu                   0.120573              0.275814
# 4zxd4tiXPlWMqoJltbVTbE                   0.613735              0.292098
# 4LInRUJ6XN1TVnoRVAFcdB                   0.194777              0.183487
# 16QhvfPMBLpo7sFqOqTff3                   0.665633              0.305937
# 2kF9Ijd7I2Kk2P4bYqUmzG                   0.266540              0.343677
# 7pKWTcPfT9mg2iAhobFHpS                   0.204244              0.374812
# 6cjjUuY51c5SwTABCVPSYH                   0.154388              0.371837
# 0jIjMIGol799k7v3kmD0ZS                   0.132966              0.291172
# 5nrpIB2dVUvhRUs5R9YJ3W                   0.990730              0.355609
# 1POLDZ0XBX9ycnCkxVKCoZ                   0.335595              0.386587
# 2d64G7VaZdHQuAquz5HQNu                   0.434343              0.244048
# 4BD61oILBbkkSojO7lcBPA                   0.655598              0.307484
# 44MyZZa2SPW0BO9XcmlU9F                   0.448438              0.444221
# 7FXj7Qg3YorUxdrzvrcY25                   0.709564              0.324648
# 0T1EaGm6b9eM7xBf4F1hlc                   0.483060              0.450869
# 08mNpIgvFDORGhekbe0n7A                   0.747475              0.370037
# 0efBjbKXXPXqUu5HmZHzW5                   0.744207              0.322501
#
#                         loudness_end_mediana  p00_C_mediana  p01_C#_mediana  \
# id
# 4d3XHYFFuYYzxWr2cJ6yQl                   0.0       0.134176        0.028520
# 3X3p3u03P8eFL8WTH0oaaU                   0.0       0.233605        0.314040
# 4KlXeaheot0OI9PoOWspvZ                   0.0       0.194633        0.110334
# 3j76McoUI18gDoqxYE14Bu                   0.0       0.242424        0.652076
# 4zxd4tiXPlWMqoJltbVTbE                   0.0       0.110269        0.107226
# 4LInRUJ6XN1TVnoRVAFcdB                   0.0       1.000000        0.815744
# 16QhvfPMBLpo7sFqOqTff3                   0.0       0.083172        0.081818
# 2kF9Ijd7I2Kk2P4bYqUmzG                   0.0       0.304058        0.114996
# 7pKWTcPfT9mg2iAhobFHpS                   0.0       0.059596        0.088889
# 6cjjUuY51c5SwTABCVPSYH                   0.0       0.839192        0.421488
# 0jIjMIGol799k7v3kmD0ZS                   0.0       0.203939        0.470328
# 5nrpIB2dVUvhRUs5R9YJ3W                   0.0       0.078762        0.133770
# 1POLDZ0XBX9ycnCkxVKCoZ                   0.0       0.601852        0.334252
# 2d64G7VaZdHQuAquz5HQNu                   0.0       0.205758        0.189899
# 4BD61oILBbkkSojO7lcBPA                   0.0       0.426369        0.280808
# 44MyZZa2SPW0BO9XcmlU9F                   0.0       0.318318        0.708333
# 7FXj7Qg3YorUxdrzvrcY25                   0.0       0.585859        0.464646
# 0T1EaGm6b9eM7xBf4F1hlc                   0.0       0.346465        0.255556
# 08mNpIgvFDORGhekbe0n7A                   0.0       0.577201        0.823013
# 0efBjbKXXPXqUu5HmZHzW5                   0.0       0.829545        0.855021
#
#                         p02_D_mediana  p03_D#_mediana  p04_E_mediana  ...  \
# id                                                                    ...
# 4d3XHYFFuYYzxWr2cJ6yQl       0.029040        0.087542       0.399711  ...
# 3X3p3u03P8eFL8WTH0oaaU       0.155303        0.098485       0.113442  ...
# 4KlXeaheot0OI9PoOWspvZ       0.189675        0.161616       0.370130  ...
# 3j76McoUI18gDoqxYE14Bu       0.598204        0.483405       0.979798  ...
# 4zxd4tiXPlWMqoJltbVTbE       0.244242        0.208754       0.082071  ...
# 4LInRUJ6XN1TVnoRVAFcdB       0.519162        0.200337       0.085859  ...
# 16QhvfPMBLpo7sFqOqTff3       0.257985        0.046465       0.027706  ...
# 2kF9Ijd7I2Kk2P4bYqUmzG       0.052525        0.104798       0.099747  ...
# 7pKWTcPfT9mg2iAhobFHpS       0.126263        0.027417       0.120435  ...
# 6cjjUuY51c5SwTABCVPSYH       0.170558        0.095960       0.158249  ...
# 0jIjMIGol799k7v3kmD0ZS       0.787603        0.728956       0.472483  ...
# 5nrpIB2dVUvhRUs5R9YJ3W       0.251515        0.309764       0.512121  ...
# 1POLDZ0XBX9ycnCkxVKCoZ       0.292105        0.314815       0.434343  ...
# 2d64G7VaZdHQuAquz5HQNu       0.143833        0.433112       0.300505  ...
# 4BD61oILBbkkSojO7lcBPA       0.288394        0.295815       0.176768  ...
# 44MyZZa2SPW0BO9XcmlU9F       0.544536        0.740260       0.350168  ...
# 7FXj7Qg3YorUxdrzvrcY25       0.428283        0.489899       0.474051  ...
# 0T1EaGm6b9eM7xBf4F1hlc       0.492063        0.373737       0.437840  ...
# 08mNpIgvFDORGhekbe0n7A       0.512626        0.915264       0.810412  ...
# 0efBjbKXXPXqUu5HmZHzW5       0.899083        0.623737       0.292929  ...
#
#                         t11_dif_iqr  pitch_dif_mediana  pitch_dif_iqr  \
# id
# 4d3XHYFFuYYzxWr2cJ6yQl     0.491252           0.473879       0.184635
# 3X3p3u03P8eFL8WTH0oaaU     0.545455           0.268316       0.624165
# 4KlXeaheot0OI9PoOWspvZ     0.055794           0.402962       0.474025
# 3j76McoUI18gDoqxYE14Bu     0.892868           0.657293       0.603615
# 4zxd4tiXPlWMqoJltbVTbE     0.504287           0.180000       0.236572
# 4LInRUJ6XN1TVnoRVAFcdB     0.480688           0.056262       0.350254
# 16QhvfPMBLpo7sFqOqTff3     0.037932           0.467657       0.225754
# 2kF9Ijd7I2Kk2P4bYqUmzG     0.677175           0.392076       0.724058
# 7pKWTcPfT9mg2iAhobFHpS     0.171223           0.471791       0.158749
# 6cjjUuY51c5SwTABCVPSYH     0.738563           0.729588       0.608884
# 0jIjMIGol799k7v3kmD0ZS     0.990002           0.927167       0.876888
# 5nrpIB2dVUvhRUs5R9YJ3W     0.521311           0.214221       0.367880
# 1POLDZ0XBX9ycnCkxVKCoZ     0.418089           0.295652       0.601036
# 2d64G7VaZdHQuAquz5HQNu     0.434049           0.253334       0.447663
# 4BD61oILBbkkSojO7lcBPA     0.155808           0.459490       0.351501
# 44MyZZa2SPW0BO9XcmlU9F     0.607373           0.084334       0.726347
# 7FXj7Qg3YorUxdrzvrcY25     0.339620           0.493516       0.538191
# 0T1EaGm6b9eM7xBf4F1hlc     0.305845           0.237451       0.310360
# 08mNpIgvFDORGhekbe0n7A     0.742358           0.215193       0.648070
# 0efBjbKXXPXqUu5HmZHzW5     0.544169           0.907750       0.709935
#
#                         pitch_mediana  pitch_iqr  timbre_dif_mediana  \
# id
# 4d3XHYFFuYYzxWr2cJ6yQl       0.023096   0.045687            0.868210
# 3X3p3u03P8eFL8WTH0oaaU       0.065758   0.084597            0.478402
# 4KlXeaheot0OI9PoOWspvZ       0.096340   0.476744            0.536099
# 3j76McoUI18gDoqxYE14Bu       0.724723   0.783911            0.487373
# 4zxd4tiXPlWMqoJltbVTbE       0.072014   0.102416            0.267625
# 4LInRUJ6XN1TVnoRVAFcdB       0.334120   0.029316            0.792929
# 16QhvfPMBLpo7sFqOqTff3       0.012399   0.023981            0.043887
# 2kF9Ijd7I2Kk2P4bYqUmzG       0.151073   0.289077            0.219433
# 7pKWTcPfT9mg2iAhobFHpS       0.015216   0.057797            0.090227
# 6cjjUuY51c5SwTABCVPSYH       0.370076   0.432507            0.738222
# 0jIjMIGol799k7v3kmD0ZS       0.474932   0.894023            0.597304
# 5nrpIB2dVUvhRUs5R9YJ3W       0.153625   0.433619            0.030755
# 1POLDZ0XBX9ycnCkxVKCoZ       0.456124   0.724634            0.145806
# 2d64G7VaZdHQuAquz5HQNu       0.113845   0.100088            0.099562
# 4BD61oILBbkkSojO7lcBPA       0.307167   0.421626            0.659860
# 44MyZZa2SPW0BO9XcmlU9F       0.583023   0.353535            0.229610
# 7FXj7Qg3YorUxdrzvrcY25       0.673483   0.738331            0.146919
# 0T1EaGm6b9eM7xBf4F1hlc       0.315286   0.348722            0.333499
# 08mNpIgvFDORGhekbe0n7A       0.655071   0.377950            0.059896
# 0efBjbKXXPXqUu5HmZHzW5       0.783063   0.507668            0.441151
#
#                         timbre_dif_iqr  timbre_mediana  timbre_iqr  genre
# id
# 4d3XHYFFuYYzxWr2cJ6yQl        0.652999        0.344643    0.936381   jazz
# 3X3p3u03P8eFL8WTH0oaaU        0.710647        0.419566    0.732306   jazz
# 4KlXeaheot0OI9PoOWspvZ        0.839182        0.190657    0.983901   jazz
# 3j76McoUI18gDoqxYE14Bu        0.939980        0.057123    0.791332   jazz
# 4zxd4tiXPlWMqoJltbVTbE        0.598742        0.459125    0.980818   jazz
# 4LInRUJ6XN1TVnoRVAFcdB        0.803821        0.476667    0.940807   jazz
# 16QhvfPMBLpo7sFqOqTff3        0.578212        0.147646    0.637678   jazz
# 2kF9Ijd7I2Kk2P4bYqUmzG        0.903448        0.127327    0.752354   jazz
# 7pKWTcPfT9mg2iAhobFHpS        0.360094        0.259385    0.605324   jazz
# 6cjjUuY51c5SwTABCVPSYH        0.875619        0.373385    0.658709   jazz
# 0jIjMIGol799k7v3kmD0ZS        0.900110        0.358347    0.758256   jazz
# 5nrpIB2dVUvhRUs5R9YJ3W        0.830337        0.358225    0.986214   jazz
# 1POLDZ0XBX9ycnCkxVKCoZ        0.609728        0.485934    0.795630   jazz
# 2d64G7VaZdHQuAquz5HQNu        0.794642        0.428109    0.886036   jazz
# 4BD61oILBbkkSojO7lcBPA        0.632249        0.122477    0.596585   jazz
# 44MyZZa2SPW0BO9XcmlU9F        0.562601        0.916391    0.622221   jazz
# 7FXj7Qg3YorUxdrzvrcY25        0.776124        0.514536    0.971234   jazz
# 0T1EaGm6b9eM7xBf4F1hlc        0.475449        0.686047    0.836949   jazz
# 08mNpIgvFDORGhekbe0n7A        0.672260        0.679204    0.632215   jazz
# 0efBjbKXXPXqUu5HmZHzW5        0.421338        0.664753    0.377848   jazz
#
# [20 rows x 125 columns]

# %%
cols = [c for c in df_num.columns if 'timbre' in c or 'pitch' in c or 'pitch' in c]
normalized_stats_25=normalized_stats_25_[cols]
normalized_stats_50=normalized_stats_50_[cols]
normalized_stats_75=normalized_stats_75_[cols]

rows=2
my_palette = sns.color_palette("Set2")
q = int(len(normalized_stats_25)/rows)+len(normalized_stats_25)%rows
fig, axs = plt.subplots(rows, q, subplot_kw=dict(polar=True))

for i in range(rows*q):
    if i<len(normalized_stats_25):
        plot_radar_chart_stats(normalized_stats_25.iloc[i],
                               normalized_stats_50.iloc[i],
                               normalized_stats_75.iloc[i],
                               my_palette[i%8],axs[i%rows, int(i/rows)])
    else:
        fig.delaxes(axs[i%rows, int(i/rows)])

#plt.savefig('radar_chart_characteristics_audio_analysis.png',dpi=800, bbox_inches = 'tight', pad_inches = 0)
#plt.show()

# %%
cols = [c for c in df_num.columns if c.lower()[:1] == 'p' and  not '_dif_' in c]
normalized_stats_25=normalized_stats_25_[cols]
normalized_stats_50=normalized_stats_50_[cols]
normalized_stats_75=normalized_stats_75_[cols]

rows=2
my_palette = sns.color_palette("Set2")
q = int(len(normalized_stats_25)/rows)+len(normalized_stats_25)%rows
fig, axs = plt.subplots(rows, q, subplot_kw=dict(polar=True))

for i in range(rows*q):
    if i<len(normalized_stats_25):
        plot_radar_chart_stats(normalized_stats_25.iloc[i],
                               normalized_stats_50.iloc[i],
                               normalized_stats_75.iloc[i],
                               my_palette[i%8],axs[i%rows, int(i/rows)])
    else:
        fig.delaxes(axs[i%rows, int(i/rows)])

#plt.savefig('radar_chart_characteristics_audio_analysis.png',dpi=800, bbox_inches = 'tight', pad_inches = 0)
#plt.show()

# %%
cols = [c for c in df_num.columns if c.lower()[:1] == 'p' and  '_dif_' in c]
normalized_stats_25=normalized_stats_25_[cols]
normalized_stats_50=normalized_stats_50_[cols]
normalized_stats_75=normalized_stats_75_[cols]

rows=2
my_palette = sns.color_palette("Set2")
q = int(len(normalized_stats_25)/rows)+len(normalized_stats_25)%rows
fig, axs = plt.subplots(rows, q, subplot_kw=dict(polar=True))

for i in range(rows*q):
    if i<len(normalized_stats_25):
        plot_radar_chart_stats(normalized_stats_25.iloc[i],
                               normalized_stats_50.iloc[i],
                               normalized_stats_75.iloc[i],
                               my_palette[i%8],axs[i%rows, int(i/rows)])
    else:
        fig.delaxes(axs[i%rows, int(i/rows)])

#plt.savefig('radar_chart_characteristics_audio_analysis.png',dpi=800, bbox_inches = 'tight', pad_inches = 0)
#plt.show()

# %%
cols = [c for c in df_num.columns if c.lower()[:1] == 't' and not '_dif_' in c]
normalized_stats_25=normalized_stats_25_[cols]
normalized_stats_50=normalized_stats_50_[cols]
normalized_stats_75=normalized_stats_75_[cols]

rows=2
my_palette = sns.color_palette("Set2")
q = int(len(normalized_stats_25)/rows)+len(normalized_stats_25)%rows
fig, axs = plt.subplots(rows, q, subplot_kw=dict(polar=True))

for i in range(rows*q):
    if i<len(normalized_stats_25):
        plot_radar_chart_stats(normalized_stats_25.iloc[i],
                               normalized_stats_50.iloc[i],
                               normalized_stats_75.iloc[i],
                               my_palette[i%8],axs[i%rows, int(i/rows)])
    else:
        fig.delaxes(axs[i%rows, int(i/rows)])

#plt.savefig('radar_chart_characteristics_audio_analysis.png',dpi=800, bbox_inches = 'tight', pad_inches = 0)
#plt.show()

# %%
cols = [c for c in df_num.columns if c.lower()[:1] == 't' and  '_dif_' in c]
normalized_stats_25=normalized_stats_25_[cols]
normalized_stats_50=normalized_stats_50_[cols]
normalized_stats_75=normalized_stats_75_[cols]

rows=2
my_palette = sns.color_palette("Set2")
q = int(len(normalized_stats_25)/rows)+len(normalized_stats_25)%rows
fig, axs = plt.subplots(rows, q, subplot_kw=dict(polar=True))

for i in range(rows*q):
    if i<len(normalized_stats_25):
        plot_radar_chart_stats(normalized_stats_25.iloc[i],
                               normalized_stats_50.iloc[i],
                               normalized_stats_75.iloc[i],
                               my_palette[i%8],axs[i%rows, int(i/rows)])
    else:
        fig.delaxes(axs[i%rows, int(i/rows)])

#plt.savefig('radar_chart_characteristics_audio_analysis.png',dpi=800, bbox_inches = 'tight', pad_inches = 0)
#plt.show()

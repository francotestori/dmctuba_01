# %%
import matplotlib.pyplot as plt
import pandas as pd 
import spotipy 
import librosa
import librosa.display
import numpy as np
import matplotlib as mpl
import urllib.request
import seaborn as sns
import tqdm
import scipy
import joblib
from pathlib import Path
from IPython.display import Audio, Markdown, Image
from spotipy.oauth2 import SpotifyClientCredentials 


# Números y Datos
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform
from scipy.interpolate import interp1d

# Análisis de sonido
import librosa
import librosa.display
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials 

from scipy.signal import savgol_filter

# Machine learning
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

sns.set_context('poster')
sns.set_style('darkgrid')

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %% [markdown]
# ### Cargar datasets

# %%
df_af = pd.read_pickle('audio_features.pickle')
df_tracks = pd.read_pickle('tracks.pickle')
df_aa = pd.read_pickle('audio_analysis.pickle').set_index('id')

# %% [markdown]
# ### Contenido de los datasets

# %%
df_af.sample(3).T
# Out:
# id                                           3Gaj5GBeZ8aynvtPkxrr9A  \
# danceability                                                  0.508
# energy                                                        0.573
# key                                                               9
# loudness                                                     -7.108
# mode                                                              1
# speechiness                                                  0.0399
# acousticness                                               0.000148
# instrumentalness                                              0.919
# liveness                                                      0.159
# valence                                                      0.0566
# tempo                                                         128.1
# type                                                 audio_features
# uri                            spotify:track:3Gaj5GBeZ8aynvtPkxrr9A
# track_href        https://api.spotify.com/v1/tracks/3Gaj5GBeZ8ay...
# analysis_url      https://api.spotify.com/v1/audio-analysis/3Gaj...
# duration_ms                                                  314907
# time_signature                                                    4
#
# id                                           444ROnaxJqiqzY0ngOgsve  \
# danceability                                                  0.582
# energy                                                        0.824
# key                                                              11
# loudness                                                     -9.453
# mode                                                              1
# speechiness                                                   0.054
# acousticness                                                  0.626
# instrumentalness                                               0.91
# liveness                                                      0.358
# valence                                                       0.698
# tempo                                                        78.672
# type                                                 audio_features
# uri                            spotify:track:444ROnaxJqiqzY0ngOgsve
# track_href        https://api.spotify.com/v1/tracks/444ROnaxJqiq...
# analysis_url      https://api.spotify.com/v1/audio-analysis/444R...
# duration_ms                                                   59480
# time_signature                                                    4
#
# id                                           2jz7vSAguRJmBHEA4I6C4N
# danceability                                                  0.515
# energy                                                        0.339
# key                                                               7
# loudness                                                    -16.457
# mode                                                              0
# speechiness                                                  0.0283
# acousticness                                                  0.823
# instrumentalness                                              0.317
# liveness                                                      0.109
# valence                                                       0.519
# tempo                                                       135.694
# type                                                 audio_features
# uri                            spotify:track:2jz7vSAguRJmBHEA4I6C4N
# track_href        https://api.spotify.com/v1/tracks/2jz7vSAguRJm...
# analysis_url      https://api.spotify.com/v1/audio-analysis/2jz7...
# duration_ms                                                  451733
# time_signature                                                    3

# %%
df_tracks.sample(3).T
# Out:
# id                                            3a2kDfmN9qDYnEUsXbXGwn  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                               Less Than Jake
# available_markets  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# disc_number                                                        1
# duration_ms                                                   194866
# explicit                                                       False
# external_ids                                {'isrc': 'USCA29800349'}
# external_urls      {'spotify': 'https://open.spotify.com/track/3a...
# href               https://api.spotify.com/v1/tracks/3a2kDfmN9qDY...
# is_local                                                       False
# name                                                           Motto
# popularity                                                        31
# preview_url                                                     None
# track_number                                                       6
# type                                                           track
# uri                             spotify:track:3a2kDfmN9qDYnEUsXbXGwn
# genre                                                            ska
#
# id                                            0PbkNsBkzlItqOC85tXCjH  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                Sied Van Riel
# available_markets                                                 []
# disc_number                                                        1
# duration_ms                                                   469975
# explicit                                                       False
# external_ids                                {'isrc': 'NLE710821111'}
# external_urls      {'spotify': 'https://open.spotify.com/track/0P...
# href               https://api.spotify.com/v1/tracks/0PbkNsBkzlIt...
# is_local                                                       False
# name                                                            Rush
# popularity                                                         0
# preview_url                                                     None
# track_number                                                      16
# type                                                           track
# uri                             spotify:track:0PbkNsBkzlItqOC85tXCjH
# genre                                                         trance
#
# id                                            3Ysj0cl3Jlb6Ysp6um8QI7
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                   Art Blakey
# available_markets  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# disc_number                                                        1
# duration_ms                                                   368746
# explicit                                                       False
# external_ids                                {'isrc': 'USBN29800796'}
# external_urls      {'spotify': 'https://open.spotify.com/track/3Y...
# href               https://api.spotify.com/v1/tracks/3Ysj0cl3Jlb6...
# is_local                                                       False
# name                                                Along Came Betty
# popularity                                                        42
# preview_url                                                     None
# track_number                                                       4
# type                                                           track
# uri                             spotify:track:3Ysj0cl3Jlb6Ysp6um8QI7
# genre                                                           jazz

# %%
df_aa.sample(3).T
# Out:
# id                                            335DUfdEUwqzDlaoI7oy1H  \
# start                                                         243.24
# duration                                                     0.26118
# confidence                                                      0.99
# loudness_start                                               -13.345
# loudness_max_time                                             0.0763
# loudness_max                                                   0.645
# loudness_end                                                       0
# pitches            [0.404, 0.261, 0.194, 0.141, 0.25, 0.176, 0.07...
# timbre             [53.022, 83.83, -35.011, -32.812, 14.217, 42.2...
#
# id                                            6KnZOnWcs2dxRCbdBZusNF  \
# start                                                        232.117
# duration                                                     0.21492
# confidence                                                     0.302
# loudness_start                                               -12.998
# loudness_max_time                                            0.00921
# loudness_max                                                  -9.402
# loudness_end                                                       0
# pitches            [0.327, 0.181, 0.045, 0.05, 0.03, 0.222, 0.76,...
# timbre             [49.11, -43.638, 7.573, -20.297, 56.075, -62.3...
#
# id                                            1oBypKRx4Va4cd2ATRx3G0
# start                                                        98.5587
# duration                                                     0.22399
# confidence                                                     0.677
# loudness_start                                               -14.238
# loudness_max_time                                            0.10311
# loudness_max                                                  -4.807
# loudness_end                                                       0
# pitches            [0.491, 0.961, 1.0, 0.725, 0.534, 0.468, 0.349...
# timbre             [50.748, 9.461, 12.749, 38.244, 7.027, -32.255...

# %% [markdown]
# ### Sampleo para una canción
# Elegimos una canción en particular y apuntamos a procesar sus series temporales

# %%
id = '7rApTY1qmoDvqq5aVq8oUs'
dff = df_tracks[df_tracks.index==id]
#dff = df_tracks.sample(1)
df_m = dff.merge(df_af, on='id', how='left').merge(df_aa, on='id', how='left')
df_m = df_m.sort_values(by=['id', 'start'], ascending=True, na_position='first')
df_m.head(3).T
# Out:
# id                                            7rApTY1qmoDvqq5aVq8oUs  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# explicit                                                       False
# external_ids                                {'isrc': 'CH4070600014'}
# external_urls      {'spotify': 'https://open.spotify.com/track/7r...
# href               https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# is_local                                                       False
# name                                        Reachers Of Civilisation
# popularity                                                         0
# preview_url                                                     None
# track_number                                                       1
# type_x                                                         track
# uri_x                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# genre                                                         trance
# danceability                                                   0.698
# energy                                                         0.563
# key                                                               11
# loudness                                                     -11.897
# mode                                                               0
# speechiness                                                   0.0479
# acousticness                                                 0.00293
# instrumentalness                                               0.814
# liveness                                                       0.069
# valence                                                       0.0648
# tempo                                                        133.993
# type_y                                                audio_features
# uri_y                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# track_href         https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# analysis_url       https://api.spotify.com/v1/audio-analysis/7rAp...
# duration_ms_y                                                 429827
# time_signature                                                     4
# start                                                              0
# duration                                                     0.31279
# confidence                                                     0.929
# loudness_start                                               -58.906
# loudness_max_time                                            0.05512
# loudness_max                                                 -47.888
# loudness_end                                                       0
# pitches            [0.438, 0.027, 0.014, 0.036, 0.03, 0.027, 0.26...
# timbre             [7.918, 63.32, -22.04, -36.254, 59.566, 8.297,...
#
# id                                            7rApTY1qmoDvqq5aVq8oUs  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# explicit                                                       False
# external_ids                                {'isrc': 'CH4070600014'}
# external_urls      {'spotify': 'https://open.spotify.com/track/7r...
# href               https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# is_local                                                       False
# name                                        Reachers Of Civilisation
# popularity                                                         0
# preview_url                                                     None
# track_number                                                       1
# type_x                                                         track
# uri_x                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# genre                                                         trance
# danceability                                                   0.698
# energy                                                         0.563
# key                                                               11
# loudness                                                     -11.897
# mode                                                               0
# speechiness                                                   0.0479
# acousticness                                                 0.00293
# instrumentalness                                               0.814
# liveness                                                       0.069
# valence                                                       0.0648
# tempo                                                        133.993
# type_y                                                audio_features
# uri_y                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# track_href         https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# analysis_url       https://api.spotify.com/v1/audio-analysis/7rAp...
# duration_ms_y                                                 429827
# time_signature                                                     4
# start                                                        0.31279
# duration                                                     0.31238
# confidence                                                     0.204
# loudness_start                                               -51.114
# loudness_max_time                                            0.19896
# loudness_max                                                 -46.826
# loudness_end                                                       0
# pitches            [0.301, 0.021, 0.003, 0.006, 0.002, 0.004, 0.2...
# timbre             [11.131, -62.519, -129.877, -105.833, 54.384, ...
#
# id                                            7rApTY1qmoDvqq5aVq8oUs
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# explicit                                                       False
# external_ids                                {'isrc': 'CH4070600014'}
# external_urls      {'spotify': 'https://open.spotify.com/track/7r...
# href               https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# is_local                                                       False
# name                                        Reachers Of Civilisation
# popularity                                                         0
# preview_url                                                     None
# track_number                                                       1
# type_x                                                         track
# uri_x                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# genre                                                         trance
# danceability                                                   0.698
# energy                                                         0.563
# key                                                               11
# loudness                                                     -11.897
# mode                                                               0
# speechiness                                                   0.0479
# acousticness                                                 0.00293
# instrumentalness                                               0.814
# liveness                                                       0.069
# valence                                                       0.0648
# tempo                                                        133.993
# type_y                                                audio_features
# uri_y                           spotify:track:7rApTY1qmoDvqq5aVq8oUs
# track_href         https://api.spotify.com/v1/tracks/7rApTY1qmoDv...
# analysis_url       https://api.spotify.com/v1/audio-analysis/7rAp...
# duration_ms_y                                                 429827
# time_signature                                                     4
# start                                                        0.62517
# duration                                                     0.17678
# confidence                                                     0.125
# loudness_start                                               -48.043
# loudness_max_time                                            0.05744
# loudness_max                                                 -46.156
# loudness_end                                                       0
# pitches            [1.0, 0.095, 0.01, 0.008, 0.028, 0.048, 0.406,...
# timbre             [13.232, -89.696, -113.508, -80.714, 59.125, -...

# %%
len(df_m)
# Out:
# 1808

# %% [markdown]
# ### Pasaje de las listas de datos (pitches y timbre) a columnas
#
# Esto es para simplificar el procesamiento y ver cómo evolucionan los datos en el tiempo.

# %%
df_m2 = df_m

pitches_nombre = ['p00_C','p01_C#','p02_D','p03_D#','p04_E','p05_F',
                 'p06_F#','p07_G','p08_G#','p09_A','p10_A#','p11_B']
df1 = pd.DataFrame(df_m2['pitches'].tolist(), columns=pitches_nombre, index=df_m2.index)
df_m2 = pd.concat([df_m2,df1],axis=1)

timbre_nombre = ['t00','t01','t02','t03','t04','t05',
                 't06','t07','t08','t09','t10','t11']
df1 = pd.DataFrame(df_m2['timbre'].tolist(), columns=timbre_nombre, index=df_m2.index)
df_m2 = pd.concat([df_m2,df1],axis=1)

df1 = None
df_m2.head(3).T
# Out:
# id                                            7rApTY1qmoDvqq5aVq8oUs  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# ...                                                              ...
# t07                                                          -16.777
# t08                                                          -27.735
# t09                                                           53.168
# t10                                                          -30.539
# t11                                                           12.689
#
# id                                            7rApTY1qmoDvqq5aVq8oUs  \
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# ...                                                              ...
# t07                                                          -16.369
# t08                                                            0.832
# t09                                                           16.384
# t10                                                            -5.82
# t11                                                           -2.761
#
# id                                            7rApTY1qmoDvqq5aVq8oUs
# album              {'album_type': 'ALBUM', 'artists': [{'external...
# artists                                                         York
# available_markets                                                 []
# disc_number                                                        1
# duration_ms_x                                                 429826
# ...                                                              ...
# t07                                                            4.723
# t08                                                          -16.189
# t09                                                            3.526
# t10                                                           -6.341
# t11                                                             8.93
#
# [67 rows x 3 columns]

# %%
df_m2.columns
# Out:
# Index(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms_x',
#        'explicit', 'external_ids', 'external_urls', 'href', 'is_local', 'name',
#        'popularity', 'preview_url', 'track_number', 'type_x', 'uri_x', 'genre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type_y', 'uri_y', 'track_href', 'analysis_url', 'duration_ms_y',
#        'time_signature', 'start', 'duration', 'confidence', 'loudness_start',
#        'loudness_max_time', 'loudness_max', 'loudness_end', 'pitches',
#        'timbre', 'p00_C', 'p01_C#', 'p02_D', 'p03_D#', 'p04_E', 'p05_F',
#        'p06_F#', 'p07_G', 'p08_G#', 'p09_A', 'p10_A#', 'p11_B', 't00', 't01',
#        't02', 't03', 't04', 't05', 't06', 't07', 't08', 't09', 't10', 't11'],
#       dtype='object')

# %% [markdown]
# ## GRÁFICOS

# %% [markdown]
# Para el suavizado de las series temporales, estamos usando el filtro de Savizky-Golay.
#
# Es para suprimir de una manera rápida el ruido sobre las series.

# %% [markdown]
# #### Confidence
#
# The confidence, from 0.0 to 1.0, of the reliability of the segmentation. Segments of the song which are difficult to logically segment (e.g: noise) may correspond to low values in this field.

# %%
q = savgol_filter(df_m2['confidence'], window_length = 101, polyorder = 3)
plt.plot(df_m2['start'],df_m2['confidence'])
plt.plot(df_m2['start'],q)

# %% [markdown]
# #### Loudness_start
#
# The onset loudness of the segment in decibels (dB). Combined with loudness_max and loudness_max_time, these components can be used to describe the “attack” of the segment.

# %%
q = savgol_filter(df_m2['loudness_start'], window_length = 101, polyorder = 3)
plt.plot(df_m2['start'],df_m2['loudness_start'])
plt.plot(df_m2['start'],q)

# %% [markdown]
# #### Loudness_max
#
# The peak loudness of the segment in decibels (dB). Combined with loudness_start and loudness_max_time, these components can be used to describe the “attack” of the segment.

# %%
q = savgol_filter(df_m2['loudness_max'], window_length = 101, polyorder = 3)
plt.plot(df_m2['start'],df_m2['loudness_max'])
plt.plot(df_m2['start'],q)

# %% [markdown]
# #### Loudness_max_time
#
# The segment-relative offset of the segment peak loudness in seconds. Combined with loudness_start and loudness_max, these components can be used to describe the “attack” of the segment.

# %%
q = savgol_filter(df_m2['loudness_max_time'], window_length = 101, polyorder = 3)
plt.plot(df_m2['start'],df_m2['loudness_max_time'])
plt.plot(df_m2['start'],q)

# %% [markdown]
# #### Loudness_end
#
# The offset loudness of the segment in decibels (dB). This value should be equivalent to the loudness_start of the following segment.

# %%
q = savgol_filter(df_m2['loudness_end'], window_length = 101, polyorder = 3)
plt.plot(df_m2['start'],df_m2['loudness_end'])
plt.plot(df_m2['start'],q)

# %% [markdown]
# #### Pitches
#
# A “chroma” vector representing the pitch content of the segment, corresponding to the 12 pitch classes C, C#, D to B, with values ranging from 0 to 1 that describe the relative dominance of every pitch in the chromatic scale.

# %%
for t in timbre_nombre:
    plt.plot(df_m2['start'],savgol_filter(df_m2[t], window_length = 101, polyorder = 3))

# %% [markdown]
# #### Timbre
#
# Timbre is the quality of a musical note or sound that distinguishes different types of musical instruments, or voices. Timbre vectors are best used in comparison with each other.

# %%
for p in pitches_nombre:
    plt.plot(df_m2['start'],savgol_filter(df_m2[p], window_length = 101, polyorder = 3))

# %%
rank_mean = df.stack().groupby(df.rank(method='first').stack().astype(int)).mean()
rank_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-fd4cdebfec1e> in <module>
# ----> 1 rank_mean = df.stack().groupby(df.rank(method='first').stack().astype(int)).mean()
#       2 rank_mean
#
# NameError: name 'df' is not defined

# %%
a = pd.DataFrame(data={'A':list(range(50)),'B':list(range(100, 0, -2))})
np.ceil(a['B'].rank().mul(50/len(a))).astype(int)

# %%
quantil=10 # decil
a = pd.DataFrame(data={'A':list(range(50)),'B':list(range(100, 0, -2))})
np.ceil(a['B'].rank().mul(quantil/len(a))).astype(int)
